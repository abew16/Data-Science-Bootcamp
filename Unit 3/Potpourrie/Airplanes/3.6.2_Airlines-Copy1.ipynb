# %% [markdown]
# # Things to do:
# ## Try to condense file size
# - Convert date columns into one DateTime column
#  - Conserve memory and remove columns for day of the week
#  - Create series with date, then concatenate with other df
# - All times are local
#  - Does that matter?
#  - If so convert to UTC (or GMT)
# - Create seperate data frames for each carrier
#  - Create a loop to do the following:
#   - Import df for carrier (n)
#   - Add that data to a model
#   - Loop until all data for every carrier is added to the model, then use that model to predict times
#
#
#
# ## Cleaning
# - Analyze NaN values and clean
#
# ## Analysis
# - Target

# %%
import numpy as np
import pandas as pd
import datetime

# %%
file = 'C:\\Users\\Abe\\Data Science Bootcamp\\Unit 3\\Potpourrie\\Airplanes\\2008_20.csv'
cols = ['Month']

df = pd.read_csv(file, usecols=cols, squeeze=True)
# Out:
# 7009728

# %%
num = 0
while num < df.shape[0]:
    df_ss = pd.read_csv(file, nrows=(num+1000), skiprows=num)
    num += 1000
    print(df_ss.head(n=1))
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        2225            WN        335        ...            4.0      8.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0          0               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
#
# [1 rows x 29 columns]
#    2008  1  3  4     834   830     955  955.1  WN  762  ...   4.2    18  0.1  \
# 0  2008  1  3  4  2059.0  1945  2220.0   2105  WN  890  ...   6.0  14.0    0
#
#    Unnamed: 22  0.2    NA NA.1 NA.2  NA.3  NA.4
# 0          NaN    0  41.0  0.0  1.0   0.0  33.0
#
# [1 rows x 29 columns]
#    2008  1  3  4    2014  1935    2129  2045  WN  1662  ...   3.1    25  0  \
# ...

# %%
file = 'C:\\Users\\Abe\\Data Science Bootcamp\\Unit 3\\Potpourrie\\Airplanes\\2008.csv'
cols = ['Year', 'Month','DayofMonth']

df = pd.read_csv(file, usecols=cols)

# %%
df.columns = ['year','month','day']
df.dtypes
# Out:
# year     int64
# month    int64
# day      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 3 columns):
# year     int64
# month    int64
# day      int64
# dtypes: int64(3)
# memory usage: 160.4 MB

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day']])
df.head()
# Out:
#    year  month  day       date
# 0  2008      1    3 2008-01-03
# 1  2008      1    3 2008-01-03
# 2  2008      1    3 2008-01-03
# 3  2008      1    3 2008-01-03
# 4  2008      1    3 2008-01-03

# %%
df.drop(['year','month','day'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 1 columns):
# date    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 53.5 MB

# %%
cols = ['DepTime', 'CRSDepTime','DepDelay']
df_dep_times = pd.read_csv(file,usecols=cols)

# %%
df_dep_times.columns = ['deptime','schddeptime','delay']
df_dep_times['delay_1'] = df_dep_times['deptime'] - df_dep_times['schddeptime']
df_dep_times.head()
# Out:
#    deptime  schddeptime  delay  delay_1
# 0   2003.0         1955    8.0     48.0
# 1    754.0          735   19.0     19.0
# 2    628.0          620    8.0      8.0
# 3    926.0          930   -4.0     -4.0
# 4   1829.0         1755   34.0     74.0

# %%
df_dep_times.drop('delay',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-883f6922b0f6> in <module>()
#       1 df_dep_times.drop('delay',axis=1,inplace=True)
# ----> 2 df_dep_times[df_dep_times.isnull()]
#
# c:\users\abe\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
# -> 2055             return self._getitem_frame(key)
#    2056         elif is_mi_columns:
#    2057             return self._getitem_multilevel(key)
#
# c:\users\abe\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    2129         if key.values.size and not is_bool_dtype(key.values):
#    2130             raise ValueError('Must pass DataFrame with boolean values only')
# ...
